# %% [markdown]
# # High-Confidence Contacts
# This notebook surfaces contacts with the strongest confidence scores so you can review the best outreach candidates first.

# %%
from pathlib import Path
import pandas as pd
import yaml
from IPython.display import display

search_root = Path.cwd()
config_path = None
for candidate in [search_root, *search_root.parents]:
    maybe = candidate / 'config.yaml'
    if maybe.exists():
        config_path = maybe
        project_root = candidate
        break
if config_path is None:
    raise FileNotFoundError("Unable to locate config.yaml from current working directory.")

cfg = yaml.safe_load(config_path.read_text()) or {}
outputs_dir = (project_root / cfg.get('outputs', {}).get('dir', 'output')).resolve()
if not outputs_dir.exists():
    raise FileNotFoundError(f"Outputs directory not found: {outputs_dir}")

contacts_path = outputs_dir / 'consolidated_contacts.csv'
confidence_path = outputs_dir / 'confidence_report.csv'
referral_path = outputs_dir / 'referral_targets.csv'
tagged_path = outputs_dir / 'tagged_contacts.csv'

confidence_df = pd.read_csv(confidence_path, dtype=str, keep_default_na=False)
contacts_df = pd.read_csv(contacts_path, dtype=str, keep_default_na=False)

high_confidence = confidence_df[confidence_df['confidence_bucket'].isin(['very_high', 'high'])].copy()
high_confidence['confidence_score'] = pd.to_numeric(high_confidence['confidence_score'], errors='coerce')

contact_columns = [
    'contact_id',
    'full_name',
    'company',
    'title',
    'source_count',
    'source_row_count',
    'emails',
    'invalid_emails',
    'phones',
    'non_standard_phones',
]
contacts_subset = contacts_df[[col for col in contact_columns if col in contacts_df.columns]].copy()
summary = high_confidence.merge(contacts_subset, on='contact_id', how='left', suffixes=('', '_contact'))
ordered_columns = [
    'contact_id',
    'full_name',
    'company',
    'title',
    'confidence_score',
    'confidence_bucket',
    'source_count',
    'source_row_count',
    'emails',
    'invalid_emails',
    'phones',
    'non_standard_phones',
]
summary = summary[[col for col in ordered_columns if col in summary.columns]]
sort_columns = [col for col in ['confidence_score', 'source_count'] if col in summary.columns]
if sort_columns:
    summary = summary.sort_values(sort_columns, ascending=[False] * len(sort_columns))
display(summary.head(25))
# Out:
#                                contact_id                 full_name  \
# 53   9aa1f347-1949-50e9-a828-ecc59d1e5669                Ben Bertka
# 54   c49f1725-1bcb-50aa-974f-98ed0b8a0324               Chris Smith
# 57   7086ffff-6ed5-5326-b865-a42021484623                Sam Herren
# 59   2c4e9e43-1ee4-56a1-8066-8ab1621473ce      Prasad Radhakrishnan
# 60   0a226778-976c-574a-95ee-b405fafc0c15            James Williams
# 61   b46bcbbe-ff5f-5995-903e-70b90bf8097c               Sean McAdam
# 63   a75908fa-8f35-51e2-8005-90a676db4367              Adam Zwickey
# 64   253e7360-8439-5190-9f0e-67363dec32dd                Nick White
# 65   9b62ad84-db1f-54b4-bdc8-6e5c92505bd4          Maurizio Carioli
# 69   2310325d-6582-5511-8a6f-077df3ea13e7     Gennadiy Mark Borisov
# 72   4c50c5dc-d6e3-5dca-807c-1d1779814299                  Zack Jha
# 77   d076988d-ace5-57ad-8c00-f95faaaa020d                   Dan Fox
# 79   ad9240c9-7d86-5e91-81fc-66362fced926             Félix Roberge
# 81   8137bb77-0915-5927-a03e-8d6be6748090            Tony Hillerson
# 82   2162db98-29de-534c-9be8-93866b426d34          Michael Campbell
# 84   afa97863-2014-5874-a7da-d13ce22a4b37  Guinevere Watson Cranton
# 88   fbc676ef-d05e-5559-b518-32c0283aa9a9              Bill DeCoste
# 89   06d0acd7-2af9-510b-a49e-1d45cecf27fe                 Jim Kelly
# 91   61078306-bf82-51b8-afa3-ba2912d7f57f          Rena Gyftopoulos
# 92   12a32f49-a24a-57ba-aa25-f1ccf84aed6f                Eyal Sivan
# 94   c775a822-e970-560d-b264-5d6b1b74c918                Hao Nguyen
# 99   5c7024b4-1005-5868-9d7a-35571adf7694              Samuel Tauil
# 100  7781b419-d6a9-502b-8906-68d69a453949              Justin Jarae
# 101  92fe82f6-639b-5686-b9ad-22ece96e334a               Bob Tierney
# 102  a1b6f222-38bf-5e68-b1aa-5231daf376e3             Steve O'Keefe
#
#                   company                                              title  \
# 53           LogicMonitor  Global Success Manager, GSI & MSP Partner Alli...
# 54                Red Hat                           Partner Alliance Manager
# 57                   SUSE  Lead for ISV Ecosystem & Channel Solutions - N...
# 59               Yugabyte                               VP Field Engineering
# 60                Elastic               Senior Principal Solutions Architect
# 61        Core Scientific                                Full Stack Engineer
# 63                 GitLab                      Principal Solutions Architect
# 64                Arelion                            Senior IP Core Engineer
# 65                Red Hat                       Principal Solution Architect
# 69        Klika Tech, Inc                                 President & Co-CEO
# 72                 Ketryx  SVP,  Worldwide Sales - Series A, Backed by Li...
# 77   Siemens Healthineers                            Senior Technical Writer
# 79                Red Hat               Senior Specialist Solution Architect
# 81              Aeris LLC                        Principal Software Engineer
# 82                 EdgeIQ                            Chief Executive Officer
# 84              Etsy Shop                                       Etsy Creator
# 88               LoftLabs                         Sales Engineer at LoftLabs
# 89                 Oracle                 Enterprise Cloud Sales, Healthcare
# 91                REG a+d                                          Principal
# 92              Ozone API                     General Manager, North America
# 94    Nine Sky Consulting                                       Founder, CEO
# 99              Microsoft                          Senior Solutions Engineer
# 100             HashiCorp                          Senior Solutions Engineer
# 101             project44                              Sr Solutions Engineer
# 102               Red Hat                      Director Product Line, Mobile
#
#      confidence_score confidence_bucket source_count source_row_count  \
# 53                100         very_high            3                4
# 54                100         very_high            3                4
# 57                100         very_high            3                4
# 59                100         very_high            3                4
# 60                100         very_high            3                4
# 61                100         very_high            3                4
# 63                100         very_high            3                4
# 64                100         very_high            3                4
# 65                100         very_high            3                4
# 69                100         very_high            3                4
# 72                100         very_high            3                4
# 77                100         very_high            3                4
# 79                100         very_high            3                4
# 81                100         very_high            3                4
# 82                100         very_high            3                4
# 84                100         very_high            3                4
# 88                100         very_high            3                4
# 89                100         very_high            3                4
# 91                100         very_high            3                4
# 92                100         very_high            3                4
# 94                100         very_high            3                4
# 99                100         very_high            3                4
# 100               100         very_high            3                4
# 101               100         very_high            3                4
# 102               100         very_high            3                4
#
#                                                 emails invalid_emails  \
# 53                bbertka@gmail.com::|ben@tetrate.io::
# 54       chris.smith@tetrate.io::|smith.chris7@pm.me::
# 57   herren.sam@gmail.com::|sam.herren@suse.com::|s...
# 59          prasad.may@gmail.com::|prasad@tetrate.io::
# 60       cloudnativeguy@gmail.com::|james@tetrate.io::
# 61             mcadams@tessco.com::|sean@fredcom.com::
# 63              adam@tetrate.io::|azwickey@gmail.com::
# 64       nick.white@edgeiq.io::|nickdwhite@gmail.com::
# 65   maurizio.carioli@gmail.com::|mcarioli@redhat.c...
# 69                           gborisov@klika-tech.com::
# 72         swapan@gmail.com::work|zackjha@amazon.com::
# 77                               danfoxart@yahoo.com::
# 79                           roberge.felix@gmail.com::
# 81   tony.hillerson@edgeiq.io::|tony.hillerson@mach...
# 82   michael@edgeiq.ai::|michael@edgeiq.io::|michae...
# 84            gilbert@cranton.com::|gwen@cranton.com::
# 88         bdecoste@gmail.com::|bill.decoste@solo.io::
# 89                              jim.kelly@oracle.com::
# 91                          sheptopoulos@comcast.net::
# 92                               eyal.sivan@cibc.com::
# 94           hao.minh@gmail.com::|hnguyen@redhat.com::
# 99                                 stauil@redhat.com::
# 100                                jjarae@redhat.com::
# 101    bob.tierney@verizon.net::|btierney@redhat.com::
# 102                               sokeefe@redhat.com::
#
#                                                 phones non_standard_phones
# 53                                 +12062148602::other
# 54                                  +19194142423::work
# 57                                +14046414700::mobile
# 59                                +13125453727::mobile
# 60                                +16782830633::mobile
# 61                   +13013254615::|+13015914113::work
# 63                                +17042584033::mobile
# 64                                +17752304642::mobile
# 65                                +16178037028::mobile
# 69             +12128428187::work|+19177703133::mobile
# 72                                +16174485917::mobile
# 77             +16175011294::mobile|+17816295703::home
# 79                                +15145018421::mobile
# 81                                +13037184016::mobile
# 82                                  +15089043334::work
# 84                                +16179499600::mobile
# 88                                +19782040920::mobile
# 89   +16178517308::mobile|+17816652445::home|+17819...
# 91   +16172684090::mobile|+16177107362::home|+16177...
# 92                                +14169010840::mobile
# 94             +17818013749::mobile|+19198118102::home
# 99             +17814754245::mobile|+18577700412::work
# 100                                 +18504455400::work
# 101                               +12146168977::mobile
# 102  +12069301843::mobile|+19783923922::home|+19785...
